# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Munic%C3%ADpio'
r = requests.get(url)
dados_municipio_rj = pd.DataFrame(r.json()['items'])

# %%
# 2) Seu código aqui
dados_municipio_rj.status.value_counts().head(3)
# Out:
# Deferido        93
# Arquivado       53
# Regularizado    25
# Name: status, dtype: int64

# %%
# 3) Seu código aqui
dados_municipio_rj['ano_status'] = dados_municipio_rj['data_status'].apply(lambda x: str(x).split('/')[2])
dados_municipio_rj
# Out:
#      id_pleito tipo_interessado            interessado  cod_ibge  uf  \
# 0        13440        Município         Rio de Janeiro   3304557  RJ
# 1        13125        Município              Vassouras   3306206  RJ
# 2        13241        Município            Barra Mansa   3300407  RJ
# 3        13653        Município        Duque de Caxias   3301702  RJ
# 4        60039        Município             Petrópolis   3303906  RJ
# ..         ...              ...                    ...       ...  ..
# 230       6363        Município              Rio Claro   3304409  RJ
# 231       9205        Município  Campos dos Goytacazes   3301009  RJ
# 232      13004        Município                 Quatis   3304128  RJ
# 233       9970        Município              Queimados   3304144  RJ
# 234       5290        Município      Casimiro de Abreu   3301306  RJ
#
#                   num_pvl        status          num_processo  \
# 0                    None      Deferido  19405.000001/2004-61
# ...

# %%
# 4)
dados_municipio_rj['ano_status'].value_counts()
# Out:
# 2008    37
# 2007    29
# 2014    20
# 2010    19
# 2019    17
# 2020    15
# 2013    15
# 2022    14
# 2012    13
# 2011    10
# 2009     9
# 2015     9
# 2021     5
# 2017     5
# 2006     4
# 2002     4
# 2018     4
# 2016     4
# 2003     1
# 2004     1
# Name: ano_status, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def retornaDadosTesouro(uf:str, interessado: str) -> pd.DataFrame:
  if(interessado == 'Municipio'):
    interessado = 'Munic%C3%ADpio'

  url = f'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf={uf}&tipo_interessado={interessado}'
  r = requests.get(url)
  if(r.status_code != 200):
    raise Exception('Erro na busca dos dados.')

  dados = pd.DataFrame(r.json()['items'])
  return dados

# %%
dados_estado_mg = retornaDadosTesouro('MG', 'Estado')
dados_estado_mg.head(3)
# Out:
#    id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 0      13695           Estado  Minas Gerais        31  MG
# 1      13672           Estado  Minas Gerais        31  MG
# 2      20458           Estado  Minas Gerais        31  MG
#
#                 num_pvl                                             status  \
# 0                  None                                          Arquivado
# 1                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2  00000.000000/2020-68                                 Arquivado a pedido
#
#            num_processo        data_protocolo  \
# 0  19405.000053/2003-57  2003-08-25T03:00:00Z
# 1  19405.000048/2005-14  2005-12-28T02:00:00Z
# 2  17944.001085/2015-81  2015-11-23T02:00:00Z
#
#                                        tipo_operacao      finalidade  \
# 0  Operação contratual externa (com garantia da U...  Infraestrutura
# 1  Operação contratual externa (com garantia da U...  Multissetorial
# ...

# %%
# 2) Seu código aqui
value_bool = dados_estado_mg['status'] == 'Arquivado por decurso de prazo'
dados_estado_mg[value_bool]['status'].value_counts()
# Out:
# Arquivado por decurso de prazo    1
# Name: status, dtype: int64

# %%
# 3) Seu código aqui
dados_municipio_ba = retornaDadosTesouro('BA', interessado='Município')
dados_municipio_ba.interessado.value_counts()
# Out:
# Camaçari                  19
# Salvador                  16
# Luís Eduardo Magalhães    15
# Amargosa                  14
# Vitória da Conquista      14
#                           ..
# Lafaiete Coutinho          1
# Serrolândia                1
# Gandu                      1
# Crisópolis                 1
# Saúde                      1
# Name: interessado, Length: 287, dtype: int64

# %%
# 4) Seu código aqui
dados_estado_ba = retornaDadosTesouro('BA','Estado')
dados_estado_ba.to_csv('dados_bahia_interessado_estado.csv', index=False)
